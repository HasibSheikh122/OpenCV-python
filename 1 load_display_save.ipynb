# %%
import numpy as np
import cv2 #opencv library

# %%
img = cv2.imread('./images/rana.jpg') #opencv bgr formet # 8bit

# %%
print(img) #3d (row, col, channel)
# Out:
# [[[ 38  49  49]
#   [ 41  52  53]
#   [ 47  58  59]
#   ...
#   [ 57  67  72]
#   [ 55  65  70]
#   [ 52  61  66]]
#
#  [[ 38  49  49]
#   [ 41  52  53]
#   [ 47  58  59]
#   ...
#   [ 60  69  75]
#   [ 54  64  69]
#   [ 50  60  65]]
#
#  [[ 38  49  49]
#   [ 42  54  54]
#   [ 47  58  59]
#   ...
#   [ 61  71  76]
#   [ 55  65  70]
#   [ 53  62  68]]
#
#  ...
#
#  [[ 47  65 100]
#   [ 44  61  97]
#   [ 40  58  93]
#   ...
#   [ 59  79 126]
#   [ 60  80 127]
#   [ 60  80 127]]
#
#  [[ 44  61  97]
#   [ 40  58  93]
#   [ 37  54  90]
#   ...
#   [ 59  79 126]
#   [ 60  80 127]
#   [ 60  80 127]]
#
#  [[ 40  58  93]
#   [ 38  55  91]
#   [ 34  52  88]
#   ...
#   [ 59  79 126]
#   [ 60  80 127]
#   [ 60  80 127]]]

# %%
img.max()
# Out:
# np.uint8(255)

# %%
img.min()
# Out:
# np.uint8(0)

# %%
img.shape
# Out:
# (1920, 1080, 3)

# %% [markdown]
# Display

# %%
cv2.imshow('orginal image', img)
cv2.waitKey(10000) # this command  will the windows for n milliseconds
cv2.destroyAllWindows()

# %%
cv2.imshow('orginal image', img)
cv2.waitKey(0) # this command dispaly the windows untaill you press x or any keyboard key
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) # assume thst image is RGB format
plt.show()

# %%
#img BGR
plt.imshow(img[:,:,[2,1,0]])
plt.show()
