# %%
import numpy as np
import cv2

# %%
img = cv2.imread('./images/car_001.jpg')

# %%
img.shape
# Out:
# (423, 678, 3)

# %%
def display(winame, image):
    cv2.imshow(winame, image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
display('cars', img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#  acess first 300 rows (hight) and first 300 columns (width) of the image (numpy array)
roi = img[0:300, 0:300]

# %%
display('acess', roi)

# %% [markdown]
# Manipulate Pixels

# %%
green_pixel = (0,255,0)
img[0:300, 0:300] = green_pixel

# %%
display('manipulate', img)
