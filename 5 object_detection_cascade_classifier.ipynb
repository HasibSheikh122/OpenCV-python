# %%
import numpy as np
import cv2

# %% [markdown]
# Face Detection

# %%
img = cv2.imread('./images/0021.jpg')
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# load cascasde classfiere - frontalface
face_cascade = cv2.CascadeClassifier('./cascade_classifier/haarcascade_frontalface_default.xml')

# %%
# apply cascade classfier to an image
faces, num_detection = face_cascade.detectMultiScale2(img)

# %%
print(faces)
# Out:
# [[114  40 196 196]]

# %%
print(num_detection)
# Out:
# [89]

# %%
pt1 = (114, 40)
pt2 = (114+196, 40+196)
#  draw the rectangle
cv2.rectangle(img, pt1, pt2, (0, 255,0))
cv2.imshow('face detection',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# draw the circle
cx =114 + 196 // 2
cy = 40 + 196 // 2
r = 196 //2

cv2.circle(img, (cx,cy), r, (0,255,255), 2)
cv2.imshow('face detection circle', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
imgh = cv2.imread('./images/hasib.jpg')
cv2.imshow('hasib',imgh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
facesh, num_detection_hasib = face_cascade.detectMultiScale2(imgh)

# %%
print(facesh)
# Out:
# [[ 71  67 162 162]]

# %%
pt1 = (71, 67)
pt2 = (71+162, 67+162)

#  draw the rectangle
cv2.rectangle(imgh, pt1, pt2, (0, 255,0))
cv2.imshow('face detection Hasib',imgh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cx =71 + 162 // 2
cy = 67 + 162 // 2
r = 196 //2

cv2.circle(imgh, (cx,cy), r, (0,0,255), 2)
cv2.imshow('face detection circle', imgh)
cv2.waitKey(0)
cv2.destroyAllWindows()
